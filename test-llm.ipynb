# %%
from transformers import pipeline

# Load the model and tokenizer
model_name = "gunzzz24/fine-tuned-tinyllama-1.1b-cv-analyser"  # You can choose other models like "gpt2-large", "facebook/opt-350m", etc.
nlp = pipeline("text-generation", model=model_name)

# Ask a question
question = "What is the capital of Norway?"

# Generate response
response = nlp(question, max_length=50, num_return_sequences=1)

# Print the response
print(response[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\github\Resume-analysis-LLM\venv\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File d:\github\Resume-analysis-LLM\venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/mistralai/Mistral-7B-v0.1/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %%
# !pip install accelerate
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: D:\github\experimentation\UK-Resume-LLM\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
from transformers import AutoTokenizer

from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "gunzzz24/fine-tuned-tinyllama-1.1b-cv-analyser", device_map="auto", load_in_4bit=True
)
tokenizer = AutoTokenizer.from_pretrained("gunzzz24/fine-tuned-tinyllama-1.1b-cv-analyser", padding_side="left")
model_inputs = tokenizer(["A list of colors: red, blue"], return_tensors="pt").to("cuda")
generated_ids = model.generate(**model_inputs)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# d:\github\Resume-analysis-LLM\venv\Lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 5
#       1 from transformers import AutoTokenizer
#       3 from transformers import AutoModelForCausalLM
# ----> 5 model = AutoModelForCausalLM.from_pretrained(
#       6     "gunzzz24/fine-tuned-tinyllama-1.1b-cv-analyser", device_map="auto", load_in_4bit=True
#       7 )
#       8 tokenizer = AutoTokenizer.from_pretrained("gunzzz24/fine-tuned-tinyllama-1.1b-cv-analyser", padding_side="left")
#       9 model_inputs = tokenizer(["A list of colors: red, blue"], return_tensors="pt").to("cuda")
#
# ...

# %%
# Define the function to count occurrences of 'ask_llm' in a string
def count_ask_llm(input_string):
    # Use the count method to find the number of occurrences
    count = input_string.count('ask_llm')
    return count

# Example usage
input_string = """main here
extract_text_from_pdf here
extract_resume_data here
extract_email here
extract_phone_number here
extract_name here
extract_portfolio_linkedin here
extract_categories here
extract_education here
extract_experiences here
generate_training_data here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
generate_answer here
ask_llm here
generate_question here
ask_llm here
"""
ask_llm_count = count_ask_llm(input_string)

print(f"The phrase 'ask_llm' appears {ask_llm_count} time(s) in the string.")
